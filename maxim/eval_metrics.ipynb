# %% [markdown]
# # MAXIM Eval Metrics (PSNR + SSIM + figura cualitativa)
#
# Notebook de evaluacion para la tesis MAXIM+MoE. Reusa el mismo entorno (clon del repo + Drive) que `maximTrainer_no_moe.ipynb` y ejecuta `tesis/eval_metrics.py`, que:
# - calcula PSNR + SSIM por tarea para los checkpoints entrenados (mono-tarea, multi-tarea y MoE),
# - imprime las filas LaTeX listas para la Tabla I de `tesis.tex`,
# - y genera la figura cualitativa `tesis/figs/fig_qualitative.pdf`.
#
# Ajustar el bloque CONFIG dentro de `tesis/eval_metrics.py` (rutas de datasets y checkpoints) antes de correr.

# %%
# %cd /content
# !git clone https://github.com/Matiata/maxim.git
# %cd /content/maxim
# !pip install -r requirements.txt
# !pip install -e .

# %%
from google.colab import drive # works only for colab
drive.mount('/content/gdrive/',)

# %% [markdown]
# # Run evaluation
#
# Ejecuta el script de evaluacion. Imprime PSNR/SSIM por tarea y las filas LaTeX, y escribe `tesis/figs/fig_qualitative.pdf`.

# %%
# %cd /content/maxim
# !python -u tesis/eval_metrics.py
